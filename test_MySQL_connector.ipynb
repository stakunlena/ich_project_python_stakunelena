# %%
import pymysql

def connect_to_db():
    '''
    Устанавливает соединение с базой данных sakila с использованием PyMySQL.
    Возвращает объект соединения или None в случае ошибки.
    '''
    config = {
        'host': 'ich-db.edu.itcareerhub.de',
        'user': 'ich1',
        'password': 'password',
        'database': 'sakila',
        'charset': 'utf8mb4',
        'cursorclass': pymysql.cursors.DictCursor
    }

    try:
        connection = pymysql.connect(**config)
        #print("Подключение к базе данных успешно.")
        return connection
    except pymysql.MySQLError as e:
        print(f"Ошибка подключения к базе данных: {e}")
        return None

def search_by_keyword(keyword): # Ищет фильмы по части названия и позволяет просматривать результаты по 10 строк.
   
    connection = connect_to_db()
    if connection is None:
        return

    try:
        with connection.cursor() as cursor:
            sql = '''
                SELECT film_id, title, description, release_year
                FROM film
                WHERE title LIKE CONCAT('%%', %s, '%%')
                ORDER BY title;
            '''
            cursor.execute(sql, (keyword,))
            results = cursor.fetchall()

            if not results:
                print("Фильмы не найдены.")
                return

            index = 0
            page_size = 10

            while index < len(results):
                page = results[index:index + page_size]
                for film in page:
                    print(f"{film['film_id']} | {film['title']} ({film['release_year']})")
                    print(f"Описание: {film['description']}\n")

                index += page_size

                if index >= len(results):
                    print("Это были все результаты.")
                    break

                cont = input("Показать следующие 10? (y/n): ").strip().lower()
                if cont != 'y':
                    print("Просмотр завершён.")
                    break

    except pymysql.MySQLError as e:
        print(f"Ошибка при выполнении запроса: {e}")
    finally:
        connection.close()

# %%
search_by_keyword("ri")
# Out:
# 5 | AFRICAN EGG (1998)
# Описание: A Fast-Paced Documentary of a Pastry Chef And a Dentist who must Pursue a Forensic Psychologist in The Gulf of Mexico
#
# 17 | ALONE TRIP (2016)
# Описание: A Fast-Paced Character Study of a Composer And a Dog who must Outgun a Boat in An Abandoned Fun House
#
# 21 | AMERICAN CIRCUS (1994)
# Описание: A Insightful Drama of a Girl And a Astronaut who must Face a Database Administrator in A Shark Tank
#
# 37 | ARIZONA BANG (2014)
# Описание: A Brilliant Panorama of a Mad Scientist And a Mad Cow who must Meet a Pioneer in A Monastery
#
# 38 | ARK RIDGEMONT (2011)
# Описание: A Beautiful Yarn of a Pioneer And a Monkey who must Pursue a Explorer in The Sahara Desert
#
# 56 | BAREFOOT MANCHURIAN (2021)
# Описание: A Intrepid Story of a Cat And a Student who must Vanquish a Girl in An Abandoned Amusement Park
#
# 63 | BEDAZZLED MARRIED (1992)
# Описание: A Astounding Character Study of a Madman And a Robot who must Meet a Mad Scientist in An Abandoned Fun House
#
# 78 | BLACKOUT PRIVATE (2023)
# Описание: A Intrepid Yarn of a Pastry Chef And a Mad Scientist who must Challenge a Secret Agent in Ancient Japan
#
# 93 | BRANNIGAN SUNRISE (1996)
# Описание: A Amazing Epistle of a Moose And a Crocodile who must Outrace a Dog in Berlin
#
# 97 | BRIDE INTRIGUE (2017)
# Описание: A Epic Tale of a Robot And a Monkey who must Vanquish a Man in New Orleans
#
# Показать следующие 10? (y/n): y
# 98 | BRIGHT ENCOUNTERS (2025)
# Описание: A Fateful Yarn of a Lumberjack And a Feminist who must Conquer a Student in A Jet Boat
#
# 99 | BRINGING HYSTERICAL (2018)
# Описание: A Fateful Saga of a A Shark And a Technical Writer who must Find a Woman in A Jet Boat
#
# 120 | CARIBBEAN LIBERTY (1998)
# Описание: A Fanciful Tale of a Pioneer And a Technical Writer who must Outgun a Pioneer in A Shark Tank
#
# 122 | CARRIE BUNCH (2007)
# Описание: A Amazing Epistle of a Student And a Astronaut who must Discover a Frisbee in The Canadian Rockies
#
# 130 | CELEBRITY HORN (2021)
# Описание: A Amazing Documentary of a Secret Agent And a Astronaut who must Vanquish a Hunter in A Shark Tank
#
# 138 | CHARIOTS CONSPIRACY (1998)
# Описание: A Unbelieveable Epistle of a Robot And a Husband who must Chase a Robot in The First Manned Space Station
#
# 149 | CHRISTMAS MOONSHINE (2015)
# Описание: A Action-Packed Epistle of a Feminist And a Astronaut who must Conquer a Boat in A Manhattan Penthouse
#
# 180 | CONSPIRACY SPIRIT (1993)
# Описание: A Awe-Inspiring Story of a Student And a Frisbee who must Conquer a Crocodile in An Abandoned Mine Shaft
#
# 203 | DAISY MENAGERIE (2002)
# Описание: A Fast-Paced Saga of a Pastry Chef And a Monkey who must Sink a Composer in Ancient India
#
# 246 | DOUBTFIRE LABYRINTH (2004)
# Описание: A Intrepid Panorama of a Butler And a Composer who must Meet a Mad Cow in The Sahara Desert
#
# Показать следующие 10? (y/n): y
# 253 | DRIFTER COMMANDMENTS (1990)
# Описание: A Epic Reflection of a Womanizer And a Squirrel who must Discover a Husband in A Jet Boat
#
# 254 | DRIVER ANNIE (2020)
# Описание: A Lacklusture Character Study of a Butler And a Car who must Redeem a Boat in An Abandoned Fun House
#
# 255 | DRIVING POLISH (2004)
# Описание: A Action-Packed Yarn of a Feminist And a Technical Writer who must Sink a Boat in An Abandoned Mine Shaft
#
# 269 | EARRING INSTINCT (1998)
# Описание: A Stunning Character Study of a Dentist And a Mad Cow who must Find a Teacher in Nigeria
#
# 298 | EYES DRIVING (1992)
# Описание: A Thrilling Story of a Cat And a Waitress who must Fight a Explorer in The Outback
#
# 308 | FERRIS MOTHER (2002)
# Описание: A Touching Display of a Frisbee And a Frisbee who must Kill a Girl in The Gulf of Mexico
#
# 311 | FICTION CHRISTMAS (2024)
# Описание: A Emotional Yarn of a A Shark And a Student who must Battle a Robot in An Abandoned Mine Shaft
#
# 337 | FRIDA SLIPPER (2025)
# Описание: A Fateful Story of a Lumberjack And a Car who must Escape a Boat in An Abandoned Mine Shaft
#
# 338 | FRISCO FORREST (2010)
# Описание: A Beautiful Documentary of a Woman And a Pioneer who must Pursue a Mad Scientist in A Shark Tank
#
# 349 | GANGS PRIDE (2022)
# Описание: A Taut Character Study of a Woman And a A Shark who must Confront a Frisbee in Berlin
#
# Показать следующие 10? (y/n): y
# 352 | GATHERING CALENDAR (1999)
# Описание: A Intrepid Tale of a Pioneer And a Moose who must Conquer a Frisbee in A MySQL Convention
#
# 365 | GOLD RIVER (2015)
# Описание: A Taut Documentary of a Database Administrator And a Waitress who must Reach a Mad Scientist in A Baloon Factory
#
# 381 | GRINCH MASSAGE (2023)
#
# 623 | NEWTON LABYRINTH (2003)
# Описание: A Intrepid Character Study of a Moose And a Waitress who must Find a A Shark in Ancient India
#
# 629 | NOTORIOUS REUNION (2002)
# Описание: A Amazing Epistle of a Woman And a Squirrel who must Fight a Hunter in A Baloon
#
# 633 | OCTOBER SUBMARINE (2000)
# Описание: A Taut Epistle of a Monkey And a Boy who must Confront a Husband in A Jet Boat
#
# 637 | OPEN AFRICAN (2005)
# Описание: A Lacklusture Drama of a Secret Agent And a Explorer who must Discover a Car in A U-Boat
#
# 643 | ORIENT CLOSER (2007)
# Описание: A Astounding Epistle of a Technical Writer And a Teacher who must Fight a Squirrel in The Sahara Desert
#
# 654 | PANKY SUBMARINE (2000)
# Описание: A Touching Documentary of a Dentist And a Sumo Wrestler who must Overcome a Boy in The Gulf of Mexico
# Показать следующие 10? (y/n): y
# 657 | PARADISE SABRINA (2003)
# Описание: A Intrepid Yarn of a Car And a Moose who must Outrace a Crocodile in A Manhattan Penthouse
#
# 658 | PARIS WEEKEND (2011)
# Описание: A Intrepid Story of a Squirrel And a Crocodile who must Defeat a Monkey in The Outback
#
# 664 | PATRIOT ROMAN (2004)
# Описание: A Taut Saga of a Robot And a Database Administrator who must Challenge a Astronaut in California
#
# 678 | PICKUP DRIVING (1995)
# Описание: A Touching Documentary of a Husband And a Boat who must Meet a Pastry Chef in A Baloon Factory
#
# 696 | PRIDE ALAMO (2007)
# Описание: A Thoughtful Drama of a A Shark And a Forensic Psychologist who must Vanquish a Student in Ancient India
#
# 697 | PRIMARY GLASS (1997)
# Описание: A Fateful Documentary of a Pastry Chef And a Butler who must Build a Dog in The Canadian Rockies
#
# 698 | PRINCESS GIANT (2024)
# Описание: A Thrilling Yarn of a Pastry Chef And a Monkey who must Battle a Monkey in A Shark Tank
#
# 699 | PRIVATE DROP (2008)
# Описание: A Stunning Story of a Technical Writer And a Hunter who must Succumb a Secret Agent in A Baloon
#
# 700 | PRIX UNDEFEATED (2003)
# Описание: A Stunning Saga of a Mad Scientist And a Boat who must Overcome a Dentist in Ancient China
#
# 729 | RIDER CADDYSHACK (1995)
# Описание: A Taut Reflection of a Monkey And a Womanizer who must Chase a Moose in Nigeria
#
# Показать следующие 10? (y/n): y
# 730 | RIDGEMONT SUBMARINE (2019)
# Описание: A Unbelieveable Drama of a Waitress And a Composer who must Sink a Mad Cow in Ancient Japan
#
# 731 | RIGHT CRANES (2003)
# Описание: A Fateful Character Study of a Boat And a Cat who must Find a Database Administrator in A Jet Boat
#
# 732 | RINGS HEARTBREAKERS (2007)
# Описание: A Amazing Yarn of a Sumo Wrestler And a Boat who must Conquer a Waitress in New Orleans
#
# 733 | RIVER OUTLAW (1993)
# Описание: A Thrilling Character Study of a Squirrel And a Lumberjack who must Face a Hunter in A MySQL Convention
#
# 736 | ROBBERY BRIGHT (2014)
# Описание: A Taut Reflection of a Robot And a Squirrel who must Fight a Boat in Ancient Japan
#
# 740 | ROLLERCOASTER BRINGING (2000)
# Описание: A Beautiful Drama of a Robot And a Lumberjack who must Discover a Technical Writer in A Shark Tank
#
# 755 | SABRINA MIDNIGHT (2017)
# Описание: A Emotional Story of a Squirrel And a Crocodile who must Succumb a Husband in The Sahara Desert
#
# 758 | SAINTS BRIDE (2009)
# Описание: A Fateful Tale of a Technical Writer And a Composer who must Pursue a Explorer in The Gulf of Mexico
#
# 761 | SANTA PARIS (2011)
# Описание: A Emotional Documentary of a Moose And a Car who must Redeem a Mad Cow in A Baloon Factory
#
# 807 | SLEUTH ORIENT (2000)
# Описание: A Fateful Character Study of a Husband And a Dog who must Find a Feminist in Ancient India
#
# Показать следующие 10? (y/n): y
# 811 | SMILE EARRING (2005)
# Описание: A Intrepid Drama of a Teacher And a Butler who must Build a Pastry Chef in Berlin
#
# 821 | SORORITY QUEEN (2018)
# Описание: A Fast-Paced Display of a Squirrel And a Composer who must Fight a Forensic Psychologist in A Jet Boat
#
# 827 | SPICE SORORITY (2011)
# Описание: A Fateful Display of a Pioneer And a Hunter who must Defeat a Husband in An Abandoned Mine Shaft
#
# 830 | SPIRIT FLINTSTONES (2013)
# Описание: A Brilliant Yarn of a Cat And a Car who must Confront a Explorer in Ancient Japan
#
# 831 | SPIRITED CASUALTIES (1990)
# Описание: A Taut Story of a Waitress And a Man who must Face a Car in A Baloon Factory
#
# 855 | STREAK RIDGEMONT (2023)
# Описание: A Astounding Character Study of a Hunter And a Waitress who must Sink a Man in New Orleans
#
# 857 | STRICTLY SCARFACE (2003)
# Описание: A Touching Reflection of a Crocodile And a Dog who must Chase a Hunter in An Abandoned Fun House
#
# 858 | SUBMARINE BED (2012)
# Описание: A Amazing Display of a Car And a Monkey who must Fight a Teacher in Soviet Georgia
#
# 865 | SUNRISE LEAGUE (1991)
# Описание: A Beautiful Epistle of a Madman And a Butler who must Face a Crocodile in A Manhattan Penthouse
#
# 868 | SUPERFLY TRIP (2024)
# Описание: A Beautiful Saga of a Lumberjack And a Teacher who must Build a Technical Writer in An Abandoned Fun House
#
# Показать следующие 10? (y/n): y
# 898 | TOURIST PELICAN (2022)
# Описание: A Boring Story of a Butler And a Astronaut who must Outrace a Pioneer in Australia
#
# 899 | TOWERS HURRICANE (2008)
# Описание: A Fateful Display of a Monkey And a Car who must Sink a Husband in A MySQL Convention
#
# 911 | TRIP NEWTON (2010)
# Описание: A Fanciful Character Study of a Lumberjack And a Car who must Discover a Cat in An Abandoned Amusement Park
#
# 919 | TYCOON GATHERING (1991)
# Описание: A Emotional Display of a Husband And a A Shark who must Succumb a Madman in A Manhattan Penthouse
#
# 926 | UNTOUCHABLES SUNRISE (1992)
# Описание: A Amazing Documentary of a Woman And a Astronaut who must Outrace a Teacher in An Abandoned Fun House
#
# 927 | UPRISING UPTOWN (1993)
# Описание: A Fanciful Reflection of a Boy And a Butler who must Pursue a Woman in Berlin
#
# 937 | VARSITY TRIP (2011)
# Описание: A Action-Packed Character Study of a Astronaut And a Explorer who must Reach a Monkey in A MySQL Convention
#
# 985 | WONDERLAND CHRISTMAS (2024)
# Описание: A Awe-Inspiring Character Study of a Waitress And a Car who must Pursue a Mad Scientist in The First Manned Space Station
#
# Это были все результаты.
